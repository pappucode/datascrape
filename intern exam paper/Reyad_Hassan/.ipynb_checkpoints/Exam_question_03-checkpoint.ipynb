# %% [markdown]
# We are excited to announce that as part of our internship selection process, we will be conducting a Jupyter Notebook exam to assess your skills and proficiency in programming. Jupyter Notebook is a powerful tool widely used in the field of data science, providing an interactive environment for coding, visualization, and documentation.

# %% [markdown]
# Your objective is to write a Python script using a web scraping library (such as BeautifulSoup or Scrapy or other library) to extract relevant information from "kathika.org" .

# %% [markdown]
# ## Data Scraping

# %% [markdown]
# import all the library

# %%
# code:
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import pandas as pd
import re
pd.set_option('display.max_rows', 120)

# %% [markdown]
# base url: https://kathika.org/

# %%
# code:
base_url="https://kathika.org/"
driver = webdriver.Chrome()

# %% [markdown]
# Extract page start from: https://kathika.org/stories

# %%
start_page= "https://kathika.org/stories?page="
story_content_page = "https://kathika.org/"

book_names = []
writer_names = []
book_links = []
book_contents = []

for i in range(1,7):
    stories_page = start_page + str(i)
    driver.get(stories_page)
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')
    stories = soup.find_all('div', class_='c-card')
    for story in stories:
        story_name = story.find('h3')
        book_names.append(story_name.text.strip())
        author_name = story.find('p').text.strip()
        writer_names.append(author_name)
        story_link = story.find('a',class_='')['href']
        book_links.append(story_link)


for i in range(len(book_links)):
    print(len(book_links)-i+1)
    url = "https://kathika.org" + book_links[i]
    driver.get(url)
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')
    content = soup.find('div', class_='story-content ql-editor')
    desc = content.find_all('p')
    string =""
    for p in desc:
        string = string + p.text.strip()
        string = string.replace("\xa0","")
        string = string.replace("\'","")
        string = string.replace("'","")
    book_contents.append(string)

# %% [markdown]
# Use **iteration** or **loop** to go through **each book** and **each page** and collect **(book name, writer name, book content)**
#
# hint: you can store data in a **list** or **dictionary**. **{"book_name":[[writer_name],[book_content]]}**
#
# caution: all the data must be contained as organized where user can tell which book belongs to which writer

# %%
# code and check
dict_kathika = {
    'book_name':book_names,
    'writer_name':writer_names,
    'book_content':book_contents
}

df = pd.DataFrame(dict_kathika)
df.to_csv(r"Kathika.csv", index=False)
df
# Out:
#                                  book_name       writer_name  \
# 0                                     চিঠি              রিদা
# 1                             পাহাড়ের চূড়া      eshrat imroz
# 2                                   পথশিশু              রিদা
# 3           সুবিমলবাবুর স্মরণীয় বাস জার্নি       Anik Biswas
# 4                     কে তুমি  (শেষ পর্ব )  Easin Arfat Moin
# 5                                  টিভিকথন       Anik Biswas
# 6                             আমি(শেষপর্ব)      eshrat imroz
# 7                              আমি (পর্ব৭)      eshrat imroz
# 8                              আমি (পর্ব৬)      eshrat imroz
# 9                              আমি (পর্ব৫)      eshrat imroz
# 10                                  আসক্তি       Anik Biswas
# 11                             আমি (পর্ব৪)      eshrat imroz
# 12                       প্রিয় জয়ন্ত স্যার       Anik Biswas
# 13                             আমি (পর্ব৩)      eshrat imroz
# 14                             আমি (পর্ব২)      eshrat imroz
# 15                              আমি চঞ্চলা              Anik
# 16                                     আমি      eshrat imroz
# 17                              জিহাদ বাবু      eshrat imroz
# 18                            রোহান বিল্লা      eshrat imroz
# 19                  তুমি অন্যনা (শেষ পর্ব)      eshrat imroz
# 20                    নীল দ্বীপ (শেষ পর্ব)      eshrat imroz
# 21                      নীল দ্বীপ (পর্ব ৭)      eshrat imroz
# 22                                 অপেক্ষা              রিদা
# 23                                আমি এমনই       Anik Biswas
# 24                    তুমি অন্যনা (পর্ব ৭)      eshrat imroz
# 25                      নীল দ্বীপ (পর্ব ৬)      eshrat imroz
# 26                       নীল দ্বীপ (পর্ব৩)      eshrat imroz
# 27                       পরীক্ষার পূর্বদিন       Anik Biswas
# 28                   তুমি অনন্যা  (পর্ব ৬)      eshrat imroz
# 29                      নীল দ্বীপ (পর্ব ৫)      eshrat imroz
# 30                    নীল দ্বীপ  ( পর্ব ৪)      eshrat imroz
# 31                   তুমি অনন্যা  (পর্ব ৫)      eshrat imroz
# 32                       নীল দ্বীপ (পর্ব২)      eshrat imroz
# 33                               নীল দ্বীপ      eshrat imroz
# 34                    তুমি অনন্যা (পর্ব ৪)      eshrat imroz
# 35                দেখা হয় নাই চক্ষু মেলিয়া       Anik Biswas
# 36                              খাঁটি পাগল       Anik Biswas
# 37                               ডাবল জিরো       Anik Biswas
# 38                    তুমি অনন্যা (পর্ব ৩)      eshrat imroz
# 39                                     রাত              Anik
# 40                   তুমি অনন্যা (পর্ব ০২)      eshrat imroz
# 41                             তুমি অনন্যা      eshrat imroz
# 42                              রিক্সাচালক              রিদা
# 43                                জুতা চোর       Anik Biswas
# 44                                   বটমূল              রিদা
# 45                                     শেষ              Anik
# 46                                 কে তুমি  Easin Arfat Moin
# 47                       আশ্চর্য এক সুগন্ধ              রিদা
# 48          ধাপ্পাবাজ বাপ্পা অথবা ধাপ্পাদা       Anik Biswas
# 49                         পড়ন্ত বিকেলে...              রিদা
# 50                        হাস্যকর এক কাণ্ড       Anik Biswas
# 51                            অদ্ভুত-উদ্ভট       Anik Biswas
# 52                            ওগো বিদেশিনী       Anik Biswas
# 53                              কুলফিওয়ালা       Anik Biswas
# 54                                 ~পিল্টু       Anik Biswas
# 55                                 সে.....              রিদা
# 56                             মাথা ব্যাথা              Anik
# 57                        দার্শনিক ফল্টুদা       Anik Biswas
# 58                               নিদ্রাহীন       Anik Biswas
# 59                                   শিকার       Anik Biswas
# 60                      ফল্টুদার পরিচয়পর্ব       Anik Biswas
# 61                              প্রতিবিম্ব       Anik Biswas
# 62   ছোট দাদুর বাড়িতে কয়েকদিন.....(পর্ব ১)              রিদা
# 63                           কেমন আছো তুমি       Anik Biswas
# 64                পাশের বিল্ডিং এর ছাদে...              রিদা
# 65                 Birthday যখন Foolday!!🎶              রিদা
# 66                          আবার ফিরে দেখা       Anik Biswas
# 67                                   আসক্ত       Anik Biswas
# 68                   কবরস্থানের মাঠে একরাত              রিদা
# 69                           শুভ্র ও রাইসা              রিদা
# 70                       উধাও ||  পর্ব - ২             অর্পন
# 71                                প্রিয় মা       Anik Biswas
# 72                               অদ্ভুতুড়ে       Anik Biswas
# 73                               কে ছিল???              রিদা
# 74                        উধাও  || পর্ব -১             অর্পন
# 75                নাম হীন গল্প - শেষের অংশ         বিজয় ঘোষ
# 76                      সপ্ন যখন হ য ব র ল              সিকন
# 77                নাম হীন গল্প - প্রথম অংশ         বিজয় ঘোষ
# 78                  আমরা তো সবাই মানুষ!!!!              রিদা
# 79                         মিষ্টি ভালোবাসা              রিদা
# 80                   "রহস্যময়ী সেই ফোন কল"            Bristy
# 81                                   করোনা              রিদা
# 82                     সব পেশাই কি সমান???              রিদা
# 83                           কিছু করার নেই       Anik Biswas
# 84                                 ছোটগল্প       Anik Biswas
# 85                                 হ্যাবলা       Anik Biswas
# 86                                   সেদিন       Anik Biswas
# 87                                  চিরকুট       Anik Biswas
# 88                                   লায়লা             অর্পন
# 89                                   অর্পন              Anik
# 90                        যখন সন্ধ্যা নামে       Anik Biswas
# 91                                      ভয়              Anik
# 92                                    মিঠু       Anik Biswas
# 93                       কয়েকদিন হাসপাতালে       Anik Biswas
# 94                                   বন্ধু       Anik Biswas
# 95                                  অনুকথন       Anik Biswas
# 96                           অ্যাক্সিডেন্ট       Anik Biswas
# 97                                ভয়ের রাত       Anik Biswas
# 98                           অমাবস্যার রাত              Anik
# 99                              দৃষ্টিগোচর              Anik
# 100                                  বিলাপ              Anik
#
#                                           book_content
# 0    রহস্যময়,জানি চিঠিটি আপনার কাছে কখনো পৌছাবে না ...
# 1    পাহাড়ের চূড়াইসরাত ইমরোজলিসা পাহাড়ের সামনে দাঁড়...
# 2    লাবণ্য, একজন পথশিশু। পথই তার বসবাস। গায়ে ছেঁড়া...
# 3    ১.সুবিমলবাবু অনেকদিন পর আজ কোথাও বেড়াতে যাচ্ছ...
# 4    কে তুমি★★শেষ অংশ…,….পিছনে তাকাতেই চোখে পড়লো এ...
# 5    আমাদের ছাদে একটি স্টোররুম আছে।ওখানে অব্যবহৃত,ভ...
# 6    তখন রাত।বসে আছি।ছাদে যেতে ইচ্ছে করছে।পূর্ণিমার...
# 7    খোলা আকাশের নিচে এসব কথা ভাবলে ভালো হতো।রাতের ...
# 8    "না আপু।""এই সেই পড়বি।গল্প পড়বি উপন্যাস পড়বি।এ...
# 9    বিচিত্র পৃথিবীর মাঝে বেঁচে আছি আমি।শুধু আমি না...
# 10   একটা আসক্তিতে জড়িয়ে আছি!যতদিন পর্যন্ত এই আসক্ত...
# 11   সকালের মিষ্টি রোদ আমার চোখে লাগছে।ঘুম ভেঙে গেল...
# 12   তখন সবে হাইস্কুলে উঠেছি।মনের মধ্যে একটা বড় হয়ে...
# 13   "এমনি দিসিলাম।কি করছিলি তখন?""ঘুমাচ্ছিলাম।""কে...
# 14   আজ পূর্ণিমা রাত।ছাদে একা এক দাঁড়িয়ে আছি।কেউ সা...
# 15   গল্প পড়ার শখ আমার অনেক দিনের আর এই শখে পরেই এক...
# 16   আমিলেখক:ইসরাত ইমরোজপর্ব:০১মানুষের হৃদয় কত রকমই...
# 17   হাসি হাসি আর হাসি রিফাহ বললো,"হাসিছ কেন?"আমি হ...
# 18   রোহান বিল্লালেখিকা:ইসরাত ইমরোজরোহান বসে আছে।বা...
# 19   রনি সেখানে যেয়ে ইসরাতকে দেখতে পেল।এই সময় নীরব ...
# 20   মৃন্ময়ের বিয়ের সবকিছু ঠিকঠাক করা হলো কেনাকাটাও...
# 21   মৃন্ময় বললো,"উনি আমাকে ভালোবাসলেও লাভ নেই।আমরা...
# 22   অপেক্ষা, এই জিনিসটা খুব বিরক্তিকর কিন্তু আবার ...
# 23   যখন চারিপাশে অশান্তি অনুভূত হয়,যখন মনের কোণে জ...
# 24   ইসরাত বললো,"ডিনার করেছেন?""হ্যা।""কখন?"৯ টায়।"...
# 25   পরদিন সকালে শুভ্র আর মৃন্ময় বের হলো।সারাটা দিন...
# 26   নীল দ্বীপ পর্ব ৩মৃন্ময় ফোন রেখে দিল।হৃদিকে বলল...
# 27   সারাবছর ভালো করে পড়েনি পিন্টু।ওর পড়ালেখা শুরু ...
# 28   রনির মন চাচ্ছে আবার দেখা করতে যায়।গোলাপ রাঙা ঠ...
# 29   মৃন্ময় খেয়াল করে দেখল শুভ্র বার বার তার দিকে ত...
# 30   মৃন্ময় বাসায় এলো।রুমে ঢুকতেই হৃদি কাছে এসে বলল...
# 31   রনি বললো," একটা কবিতা বলি।""বলেন।"     অম্বর থ...
# 32   ব্রেকফাস্ট শেষে মৃন্ময় তার রুমে গেল।একটু পরে হ...
# 33   লেখক :ইসরাত ইমরোজপর্ব:০১মৃন্ময় ছাদে একা দাঁড়িয়...
# 34   ইসরাত কাছে এসে বললো,"আচ্ছা।"রনি ইসরাতের দিকে ত...
# 35   ❝বহু দিন ধরে, বহু ক্রোশ দূরেবহু ব্যয় করিবহু দে...
# 36   বিধূবাবুর কাছে এক পাগল এসে দাঁড়িয়ে রইল।বিধূবাব...
# 37   অংক পরীক্ষায় একেবারে দুটো শূন্য, যাকে বলে "ডাব...
# 38   পর্ব ৩:একটু এগুনোর পর শান্ত কল দিল।কল ধরে রনি ...
# 39   সোউউ… করে একটা অটো চলে গেলো সিকনের সামনে দিয়ে।...
# 40   তুমি অনন্যালেখক:ইসরাত ইমরোজপর্ব:০২রনি ঘরে ঢুকত...
# 41   তুমি অনন্যালেখক:ইসরাত ইমরোজপর্ব :০১বসন্তের বিক...
# 42   প্রখর রোদে দাড়িয়ে আছে আয়মান। আজকে সে তার সাইকে...
# 43   এই বিশুটা জুতা চুরি করে কি আনন্দ যে পায় — বুঝি...
# 44   ছুটির ঘন্টা পড়ে গেল....আমি আমার আপুর জন্য অপে...
# 45   ফোন রিং হওয়ার শব্দ হচ্ছে…→ হ্যালো..→ একা থাকতে...
# 46   "কে তুমি "...,পিছনে তাকাতেই চোখ পড়লো এক অদ্ভুত...
# 47   লেখিকাঃ রোদেলা রিদাএকবারের ঘটনা,আমার পড়ার টেবি...
# 48   —বাপ্পাদার নাম যেভাবে ধাপ্পাদা হলো—বাপ্পাদা হা...
# 49   পড়ন্ত বিকেলে...সারাদিন ঝিরিঝিরি বৃষ্টির পর এই ...
# 50   কয়েকদিন আগের কথা।আমি যে স্যারের বাসায় টিউশন পড়...
# 51   এ কোথায় এলাম আমি?হঠাৎ দেখছি,হুবহু দেখতে তিনটা ...
# 52   ‘অ্যান্জেলা ’ নাম ওর।নামটা বিদেশি টাইপের তাই ও...
# 53   কুলফি খেতে ভীষণ ভালোবাসে অন্তু।স্কুলে প্রতিদিন...
# 54   রেলস্টেশনটার পিছনের দিকের যে বস্তিটা আছে,সেই ব...
# 55   এক নিমষেই কি সব শেষ হয়? না হয় না...হয়তো কোনো এ...
# 56   কপালের ডানপাশটা ব্যাথা করছে। ডান চোখের ঠিক উপর...
# 57   দার্শনিক ফল্টুদা —ফল্টুদার মাথায় কদিন ধরে আবার...
# 58   রাতে যখন সবাই ঘুমিয়ে পড়ে,সব নিরব থাকে—কিন্তু য...
# 59   রাত ১ঃ৩০টা।অমাবস্যার রাত।চারদিকে নিকষ কালো অন্...
# 60   ১.ফল্টুদার নামের ইতিকথা—ফল্টুদার আসল নাম পল্টু...
# 61   আয়নার সামনে বসে নিজেকে দেখছিলাম। অনেকক্ষণ তাকি...
# 62   ছোট দাদুর বাড়িতে কয়েকদিন....( পর্ব ১)লেখিকাঃ র...
# 63   নিলিকে আমি আমার মনের কথাটা বলতে পারি নি। খুব ভ...
# 64   পাশের বিল্ডিং এর ছাদে...লেখিকাঃ রোদেলা রিদাসিঁ...
# 65   Birthday যখন Foolday🎶লেখিকাঃ রোদেলা রিদাসূর্যে...
# 66   “ ঈপ্সিতা” ডাকটা শুনে পিছনে ফিরে তাকালো ও।গত ৫...
# 67   ১.আমি ভিডিওগেম আসক্ত। এই আসক্তি আমার সব শেষ কর...
# 68   কবরস্থানের মাঠে একরাতলেখিকাঃ রোদেলা রিদাএকবার ...
# 69   বিকাল বেলা বাহিরে মেঘ ডাকছে, গুঢ় গুঢ় শব্দ করছে...
# 70   পর্ব একের পর …রামিম একজন প্রগ্রামার । তার লেখা...
# 71   প্রিয় মা,কেমন আছো তুমি?ভালো আছো তো?তুমি সবসময় ...
# 72   কদিন আগে আমি পিসির বাড়ি বেড়াতে গিয়েছিলাম।অনেকদ...
# 73   আমি আগে ৯ -১০ টার মধ্যেই ঘুমায় পড়তাম, কিন্তু এ...
# 74   ৬৬ সালের মে মাস…. প্রমাণ হয়ে গেলো আলোর বেগের ক...
# 75   প্রথম অংশের পর…তখন আমি লাশকাটায় পারদর্শী । আমা...
# 76   আমি এখন বিয়ে বাড়িতে বাল্য বন্ধুর বাল্য বিবাহ খ...
# 77   কিছু গল্পের কোনো নাম থাকে না এটাও তেমনি একটা ন...
# 78   তখন আমি ক্লাস 5 এ পড়ি,স্কুল থেকে বের হওয়ার সময়...
# 79   বউটা আজকে আমার উপর অনেক অভিমানকরে আছে। অভিমান ...
# 80   রাত ১০ টা বেজে ৩০ মিনিট (জারা জেগে জেগে ঘুমাচ্...
# 81   নাম ছিলো তার করোনা। খুব ছোট ছিলো যখন ওর জাতি ম...
# 82   সবাই বলে সব পেশাই সমান!সত্যি কি তাই?! না সত্যি...
# 83   ১.আজকালকার দিনে চাকরি পাওয়াটা খুবই দুরূহ ব্যাপ...
# 84   আমি গল্প লিখি। তবে লেখক না,শখের বশে লিখি আর কি...
# 85   গ্রামের নাম পলাশপুর।গ্রামটি এত সুন্দর যে,মনে হ...
# 86   আজ সকাল থেকেই আকাশটা কেমন সাজ ধরে আছে। বৃষ্টি ...
# 87   এই গল্পটা আমার না।এটা অন্যদুজনের গল্প। যার শুর...
# 88   "তুমি ছুয়ে দিলে হায়, কিযে হয়ে যায়"এই দুই লাইন ...
# 89   ভোরের সূর্য উঠার ঠিক আগ মুহূর্ত...অর্পনের ঘুম ...
# 90   প্রতিদিন যখন সন্ধ্যা নামে আমি আর ত্রিধা এই নদী...
# 91   ছোট বেলার থেকেই আমি ছিলাম একটু দুর্বল হৃদয়ের ম...
# 92   আমি মিঠু। পুরো নাম মিঠু বিশ্বাস। পড়ালেখা করি ন...
# 93   একবার আমার কয়েকদিন হাসপাতালে থাকার দূর্ভাগ্য হ...
# 94   রিজু,আমার বেস্ট ফ্রেন্ড।আমরা যখন ক্লাস ফোরে পড়...
# 95   অন্নদার ডাক নাম অনু।অনুর বাবা-মা মারা গেছে সে ...
# 96   অ্যাক্সিডেন্টআজ আমি ভীষণ খুশি —বাবা-মা সবাই খু...
# 97   ভয়ের রাতচিন্টুর শরীরটা বেশি ভালো না আজ।জ্বর-জ্...
# 98   গল্পটা খুব আগের না এইতো এই পূর্ণিমাতে হবে ৭ দি...
# 99   জীবনে অসফল এক ব্যাক্তি আমি। জীবনের অবসান যেহেত...
# 100  আচ্ছা আমরা কি ভালোবাসি?শরীর নাকি মন? নাকি সুন্...

# %% [markdown]
# Save current Data as json or other format in you're local mechine.
#
# caution: you must be able to read it in jupyter notebook

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# import saved data in jupyter notebook

# %%
# code:
df1 = pd.read_csv("Kathika.csv")
df1
# Out:
#                                  book_name       writer_name  \
# 0                                     চিঠি              রিদা
# 1                             পাহাড়ের চূড়া      eshrat imroz
# 2                                   পথশিশু              রিদা
# 3           সুবিমলবাবুর স্মরণীয় বাস জার্নি       Anik Biswas
# 4                     কে তুমি  (শেষ পর্ব )  Easin Arfat Moin
# 5                                  টিভিকথন       Anik Biswas
# 6                             আমি(শেষপর্ব)      eshrat imroz
# 7                              আমি (পর্ব৭)      eshrat imroz
# 8                              আমি (পর্ব৬)      eshrat imroz
# 9                              আমি (পর্ব৫)      eshrat imroz
# 10                                  আসক্তি       Anik Biswas
# 11                             আমি (পর্ব৪)      eshrat imroz
# 12                       প্রিয় জয়ন্ত স্যার       Anik Biswas
# 13                             আমি (পর্ব৩)      eshrat imroz
# 14                             আমি (পর্ব২)      eshrat imroz
# 15                              আমি চঞ্চলা              Anik
# 16                                     আমি      eshrat imroz
# 17                              জিহাদ বাবু      eshrat imroz
# 18                            রোহান বিল্লা      eshrat imroz
# 19                  তুমি অন্যনা (শেষ পর্ব)      eshrat imroz
# 20                    নীল দ্বীপ (শেষ পর্ব)      eshrat imroz
# 21                      নীল দ্বীপ (পর্ব ৭)      eshrat imroz
# 22                                 অপেক্ষা              রিদা
# 23                                আমি এমনই       Anik Biswas
# 24                    তুমি অন্যনা (পর্ব ৭)      eshrat imroz
# 25                      নীল দ্বীপ (পর্ব ৬)      eshrat imroz
# 26                       নীল দ্বীপ (পর্ব৩)      eshrat imroz
# 27                       পরীক্ষার পূর্বদিন       Anik Biswas
# 28                   তুমি অনন্যা  (পর্ব ৬)      eshrat imroz
# 29                      নীল দ্বীপ (পর্ব ৫)      eshrat imroz
# 30                    নীল দ্বীপ  ( পর্ব ৪)      eshrat imroz
# 31                   তুমি অনন্যা  (পর্ব ৫)      eshrat imroz
# 32                       নীল দ্বীপ (পর্ব২)      eshrat imroz
# 33                               নীল দ্বীপ      eshrat imroz
# 34                    তুমি অনন্যা (পর্ব ৪)      eshrat imroz
# 35                দেখা হয় নাই চক্ষু মেলিয়া       Anik Biswas
# 36                              খাঁটি পাগল       Anik Biswas
# 37                               ডাবল জিরো       Anik Biswas
# 38                    তুমি অনন্যা (পর্ব ৩)      eshrat imroz
# 39                                     রাত              Anik
# 40                   তুমি অনন্যা (পর্ব ০২)      eshrat imroz
# 41                             তুমি অনন্যা      eshrat imroz
# 42                              রিক্সাচালক              রিদা
# 43                                জুতা চোর       Anik Biswas
# 44                                   বটমূল              রিদা
# 45                                     শেষ              Anik
# 46                                 কে তুমি  Easin Arfat Moin
# 47                       আশ্চর্য এক সুগন্ধ              রিদা
# 48          ধাপ্পাবাজ বাপ্পা অথবা ধাপ্পাদা       Anik Biswas
# 49                         পড়ন্ত বিকেলে...              রিদা
# 50                        হাস্যকর এক কাণ্ড       Anik Biswas
# 51                            অদ্ভুত-উদ্ভট       Anik Biswas
# 52                            ওগো বিদেশিনী       Anik Biswas
# 53                              কুলফিওয়ালা       Anik Biswas
# 54                                 ~পিল্টু       Anik Biswas
# 55                                 সে.....              রিদা
# 56                             মাথা ব্যাথা              Anik
# 57                        দার্শনিক ফল্টুদা       Anik Biswas
# 58                               নিদ্রাহীন       Anik Biswas
# 59                                   শিকার       Anik Biswas
# 60                      ফল্টুদার পরিচয়পর্ব       Anik Biswas
# 61                              প্রতিবিম্ব       Anik Biswas
# 62   ছোট দাদুর বাড়িতে কয়েকদিন.....(পর্ব ১)              রিদা
# 63                           কেমন আছো তুমি       Anik Biswas
# 64                পাশের বিল্ডিং এর ছাদে...              রিদা
# 65                 Birthday যখন Foolday!!🎶              রিদা
# 66                          আবার ফিরে দেখা       Anik Biswas
# 67                                   আসক্ত       Anik Biswas
# 68                   কবরস্থানের মাঠে একরাত              রিদা
# 69                           শুভ্র ও রাইসা              রিদা
# 70                       উধাও ||  পর্ব - ২             অর্পন
# 71                                প্রিয় মা       Anik Biswas
# 72                               অদ্ভুতুড়ে       Anik Biswas
# 73                               কে ছিল???              রিদা
# 74                        উধাও  || পর্ব -১             অর্পন
# 75                নাম হীন গল্প - শেষের অংশ         বিজয় ঘোষ
# 76                      সপ্ন যখন হ য ব র ল              সিকন
# 77                নাম হীন গল্প - প্রথম অংশ         বিজয় ঘোষ
# 78                  আমরা তো সবাই মানুষ!!!!              রিদা
# 79                         মিষ্টি ভালোবাসা              রিদা
# 80                   "রহস্যময়ী সেই ফোন কল"            Bristy
# 81                                   করোনা              রিদা
# 82                     সব পেশাই কি সমান???              রিদা
# 83                           কিছু করার নেই       Anik Biswas
# 84                                 ছোটগল্প       Anik Biswas
# 85                                 হ্যাবলা       Anik Biswas
# 86                                   সেদিন       Anik Biswas
# 87                                  চিরকুট       Anik Biswas
# 88                                   লায়লা             অর্পন
# 89                                   অর্পন              Anik
# 90                        যখন সন্ধ্যা নামে       Anik Biswas
# 91                                      ভয়              Anik
# 92                                    মিঠু       Anik Biswas
# 93                       কয়েকদিন হাসপাতালে       Anik Biswas
# 94                                   বন্ধু       Anik Biswas
# 95                                  অনুকথন       Anik Biswas
# 96                           অ্যাক্সিডেন্ট       Anik Biswas
# 97                                ভয়ের রাত       Anik Biswas
# 98                           অমাবস্যার রাত              Anik
# 99                              দৃষ্টিগোচর              Anik
# 100                                  বিলাপ              Anik
#
#                                           book_content
# 0    রহস্যময়,জানি চিঠিটি আপনার কাছে কখনো পৌছাবে না ...
# 1    পাহাড়ের চূড়াইসরাত ইমরোজলিসা পাহাড়ের সামনে দাঁড়...
# 2    লাবণ্য, একজন পথশিশু। পথই তার বসবাস। গায়ে ছেঁড়া...
# 3    ১.সুবিমলবাবু অনেকদিন পর আজ কোথাও বেড়াতে যাচ্ছ...
# 4    কে তুমি★★শেষ অংশ…,….পিছনে তাকাতেই চোখে পড়লো এ...
# 5    আমাদের ছাদে একটি স্টোররুম আছে।ওখানে অব্যবহৃত,ভ...
# 6    তখন রাত।বসে আছি।ছাদে যেতে ইচ্ছে করছে।পূর্ণিমার...
# 7    খোলা আকাশের নিচে এসব কথা ভাবলে ভালো হতো।রাতের ...
# 8    "না আপু।""এই সেই পড়বি।গল্প পড়বি উপন্যাস পড়বি।এ...
# 9    বিচিত্র পৃথিবীর মাঝে বেঁচে আছি আমি।শুধু আমি না...
# 10   একটা আসক্তিতে জড়িয়ে আছি!যতদিন পর্যন্ত এই আসক্ত...
# 11   সকালের মিষ্টি রোদ আমার চোখে লাগছে।ঘুম ভেঙে গেল...
# 12   তখন সবে হাইস্কুলে উঠেছি।মনের মধ্যে একটা বড় হয়ে...
# 13   "এমনি দিসিলাম।কি করছিলি তখন?""ঘুমাচ্ছিলাম।""কে...
# 14   আজ পূর্ণিমা রাত।ছাদে একা এক দাঁড়িয়ে আছি।কেউ সা...
# 15   গল্প পড়ার শখ আমার অনেক দিনের আর এই শখে পরেই এক...
# 16   আমিলেখক:ইসরাত ইমরোজপর্ব:০১মানুষের হৃদয় কত রকমই...
# 17   হাসি হাসি আর হাসি রিফাহ বললো,"হাসিছ কেন?"আমি হ...
# 18   রোহান বিল্লালেখিকা:ইসরাত ইমরোজরোহান বসে আছে।বা...
# 19   রনি সেখানে যেয়ে ইসরাতকে দেখতে পেল।এই সময় নীরব ...
# 20   মৃন্ময়ের বিয়ের সবকিছু ঠিকঠাক করা হলো কেনাকাটাও...
# 21   মৃন্ময় বললো,"উনি আমাকে ভালোবাসলেও লাভ নেই।আমরা...
# 22   অপেক্ষা, এই জিনিসটা খুব বিরক্তিকর কিন্তু আবার ...
# 23   যখন চারিপাশে অশান্তি অনুভূত হয়,যখন মনের কোণে জ...
# 24   ইসরাত বললো,"ডিনার করেছেন?""হ্যা।""কখন?"৯ টায়।"...
# 25   পরদিন সকালে শুভ্র আর মৃন্ময় বের হলো।সারাটা দিন...
# 26   নীল দ্বীপ পর্ব ৩মৃন্ময় ফোন রেখে দিল।হৃদিকে বলল...
# 27   সারাবছর ভালো করে পড়েনি পিন্টু।ওর পড়ালেখা শুরু ...
# 28   রনির মন চাচ্ছে আবার দেখা করতে যায়।গোলাপ রাঙা ঠ...
# 29   মৃন্ময় খেয়াল করে দেখল শুভ্র বার বার তার দিকে ত...
# 30   মৃন্ময় বাসায় এলো।রুমে ঢুকতেই হৃদি কাছে এসে বলল...
# 31   রনি বললো," একটা কবিতা বলি।""বলেন।"     অম্বর থ...
# 32   ব্রেকফাস্ট শেষে মৃন্ময় তার রুমে গেল।একটু পরে হ...
# 33   লেখক :ইসরাত ইমরোজপর্ব:০১মৃন্ময় ছাদে একা দাঁড়িয়...
# 34   ইসরাত কাছে এসে বললো,"আচ্ছা।"রনি ইসরাতের দিকে ত...
# 35   ❝বহু দিন ধরে, বহু ক্রোশ দূরেবহু ব্যয় করিবহু দে...
# 36   বিধূবাবুর কাছে এক পাগল এসে দাঁড়িয়ে রইল।বিধূবাব...
# 37   অংক পরীক্ষায় একেবারে দুটো শূন্য, যাকে বলে "ডাব...
# 38   পর্ব ৩:একটু এগুনোর পর শান্ত কল দিল।কল ধরে রনি ...
# 39   সোউউ… করে একটা অটো চলে গেলো সিকনের সামনে দিয়ে।...
# 40   তুমি অনন্যালেখক:ইসরাত ইমরোজপর্ব:০২রনি ঘরে ঢুকত...
# 41   তুমি অনন্যালেখক:ইসরাত ইমরোজপর্ব :০১বসন্তের বিক...
# 42   প্রখর রোদে দাড়িয়ে আছে আয়মান। আজকে সে তার সাইকে...
# 43   এই বিশুটা জুতা চুরি করে কি আনন্দ যে পায় — বুঝি...
# 44   ছুটির ঘন্টা পড়ে গেল....আমি আমার আপুর জন্য অপে...
# 45   ফোন রিং হওয়ার শব্দ হচ্ছে…→ হ্যালো..→ একা থাকতে...
# 46   "কে তুমি "...,পিছনে তাকাতেই চোখ পড়লো এক অদ্ভুত...
# 47   লেখিকাঃ রোদেলা রিদাএকবারের ঘটনা,আমার পড়ার টেবি...
# 48   —বাপ্পাদার নাম যেভাবে ধাপ্পাদা হলো—বাপ্পাদা হা...
# 49   পড়ন্ত বিকেলে...সারাদিন ঝিরিঝিরি বৃষ্টির পর এই ...
# 50   কয়েকদিন আগের কথা।আমি যে স্যারের বাসায় টিউশন পড়...
# 51   এ কোথায় এলাম আমি?হঠাৎ দেখছি,হুবহু দেখতে তিনটা ...
# 52   ‘অ্যান্জেলা ’ নাম ওর।নামটা বিদেশি টাইপের তাই ও...
# 53   কুলফি খেতে ভীষণ ভালোবাসে অন্তু।স্কুলে প্রতিদিন...
# 54   রেলস্টেশনটার পিছনের দিকের যে বস্তিটা আছে,সেই ব...
# 55   এক নিমষেই কি সব শেষ হয়? না হয় না...হয়তো কোনো এ...
# 56   কপালের ডানপাশটা ব্যাথা করছে। ডান চোখের ঠিক উপর...
# 57   দার্শনিক ফল্টুদা —ফল্টুদার মাথায় কদিন ধরে আবার...
# 58   রাতে যখন সবাই ঘুমিয়ে পড়ে,সব নিরব থাকে—কিন্তু য...
# 59   রাত ১ঃ৩০টা।অমাবস্যার রাত।চারদিকে নিকষ কালো অন্...
# 60   ১.ফল্টুদার নামের ইতিকথা—ফল্টুদার আসল নাম পল্টু...
# 61   আয়নার সামনে বসে নিজেকে দেখছিলাম। অনেকক্ষণ তাকি...
# 62   ছোট দাদুর বাড়িতে কয়েকদিন....( পর্ব ১)লেখিকাঃ র...
# 63   নিলিকে আমি আমার মনের কথাটা বলতে পারি নি। খুব ভ...
# 64   পাশের বিল্ডিং এর ছাদে...লেখিকাঃ রোদেলা রিদাসিঁ...
# 65   Birthday যখন Foolday🎶লেখিকাঃ রোদেলা রিদাসূর্যে...
# 66   “ ঈপ্সিতা” ডাকটা শুনে পিছনে ফিরে তাকালো ও।গত ৫...
# 67   ১.আমি ভিডিওগেম আসক্ত। এই আসক্তি আমার সব শেষ কর...
# 68   কবরস্থানের মাঠে একরাতলেখিকাঃ রোদেলা রিদাএকবার ...
# 69   বিকাল বেলা বাহিরে মেঘ ডাকছে, গুঢ় গুঢ় শব্দ করছে...
# 70   পর্ব একের পর …রামিম একজন প্রগ্রামার । তার লেখা...
# 71   প্রিয় মা,কেমন আছো তুমি?ভালো আছো তো?তুমি সবসময় ...
# 72   কদিন আগে আমি পিসির বাড়ি বেড়াতে গিয়েছিলাম।অনেকদ...
# 73   আমি আগে ৯ -১০ টার মধ্যেই ঘুমায় পড়তাম, কিন্তু এ...
# 74   ৬৬ সালের মে মাস…. প্রমাণ হয়ে গেলো আলোর বেগের ক...
# 75   প্রথম অংশের পর…তখন আমি লাশকাটায় পারদর্শী । আমা...
# 76   আমি এখন বিয়ে বাড়িতে বাল্য বন্ধুর বাল্য বিবাহ খ...
# 77   কিছু গল্পের কোনো নাম থাকে না এটাও তেমনি একটা ন...
# 78   তখন আমি ক্লাস 5 এ পড়ি,স্কুল থেকে বের হওয়ার সময়...
# 79   বউটা আজকে আমার উপর অনেক অভিমানকরে আছে। অভিমান ...
# 80   রাত ১০ টা বেজে ৩০ মিনিট (জারা জেগে জেগে ঘুমাচ্...
# 81   নাম ছিলো তার করোনা। খুব ছোট ছিলো যখন ওর জাতি ম...
# 82   সবাই বলে সব পেশাই সমান!সত্যি কি তাই?! না সত্যি...
# 83   ১.আজকালকার দিনে চাকরি পাওয়াটা খুবই দুরূহ ব্যাপ...
# 84   আমি গল্প লিখি। তবে লেখক না,শখের বশে লিখি আর কি...
# 85   গ্রামের নাম পলাশপুর।গ্রামটি এত সুন্দর যে,মনে হ...
# 86   আজ সকাল থেকেই আকাশটা কেমন সাজ ধরে আছে। বৃষ্টি ...
# 87   এই গল্পটা আমার না।এটা অন্যদুজনের গল্প। যার শুর...
# 88   "তুমি ছুয়ে দিলে হায়, কিযে হয়ে যায়"এই দুই লাইন ...
# 89   ভোরের সূর্য উঠার ঠিক আগ মুহূর্ত...অর্পনের ঘুম ...
# 90   প্রতিদিন যখন সন্ধ্যা নামে আমি আর ত্রিধা এই নদী...
# 91   ছোট বেলার থেকেই আমি ছিলাম একটু দুর্বল হৃদয়ের ম...
# 92   আমি মিঠু। পুরো নাম মিঠু বিশ্বাস। পড়ালেখা করি ন...
# 93   একবার আমার কয়েকদিন হাসপাতালে থাকার দূর্ভাগ্য হ...
# 94   রিজু,আমার বেস্ট ফ্রেন্ড।আমরা যখন ক্লাস ফোরে পড়...
# 95   অন্নদার ডাক নাম অনু।অনুর বাবা-মা মারা গেছে সে ...
# 96   অ্যাক্সিডেন্টআজ আমি ভীষণ খুশি —বাবা-মা সবাই খু...
# 97   ভয়ের রাতচিন্টুর শরীরটা বেশি ভালো না আজ।জ্বর-জ্...
# 98   গল্পটা খুব আগের না এইতো এই পূর্ণিমাতে হবে ৭ দি...
# 99   জীবনে অসফল এক ব্যাক্তি আমি। জীবনের অবসান যেহেত...
# 100  আচ্ছা আমরা কি ভালোবাসি?শরীর নাকি মন? নাকি সুন্...

# %% [markdown]
# Check if **book_content** contains any html element or other element which is not suppose to be there.

# %%
# Ans: Yes or No
# No
html_element = re.compile(r'<.*?>')
df1['contains_html'] = df1['book_content'].apply(lambda x: bool(html_element.search(str(x))))

# %% [markdown]
# If Answer is Yes then remove those element
#
# hint: use library **re** or other library
#
# caution: book content must maintain their Integrity

# %%
# code:
df1['contains_html'].value_counts()
# Out:
# contains_html
# False    101
# Name: count, dtype: int64

# %% [markdown]
# Check how many stories or books you've collected and how many stories or books does website have

# %%
# code
story_count=[]
for i in range(1,7):
    stories_page = start_page + str(i)
    driver.get(stories_page)
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')
    stories = soup.find_all('div', class_='c-card')
    for story in stories:
        story_name = story.find('h3')
        story_count.append(story_name.text.strip())

print(f"Number of stories or book webite has: {len(story_count)}\nNumber of collected stories: {df1['book_name'].value_counts().sum()}" )
# Out:
# Number of stories or book webite has: 101
# Number of collected stories: 101

# %% [markdown]
# Did your books count matches with website? Yes or no

# %%
# Ans: Yes or No
Yes

# %% [markdown]
# ### If your books count does not match then check your code and find the bug and fix it.

# %% [markdown]
# If your books count matches then print all writer name and how many book each writer wrote.
#
# print hint: print(writer name: "name", number of book: "number")

# %%
# code:
writer_book_count = df1.groupby('writer_name')['book_name'].count()

for i in range(len(writer_book_count)):
    print(f"writer name: {writer_book_count.index[i]}, number of book: {writer_book_count[i]} ")
# Out:
# writer name: Anik, number of book: 9
# writer name: Anik Biswas, number of book: 38
# writer name: Bristy, number of book: 1
# writer name: Easin Arfat Moin, number of book: 2
# writer name: eshrat imroz, number of book: 27
# writer name: অর্পন, number of book: 3
# writer name: বিজয় ঘোষ, number of book: 2
# writer name: রিদা, number of book: 18
# writer name: সিকন, number of book: 1

# %% [markdown]
# Save each books as **txt** file. where file name is **book_name.txt**. inside that file is **book_content**.
#
# Save each **book_name** and **writer_name** in **csv** file.

# %%
#code:


# Saving books containing book_content as txt file
pattern_to_eliminate = r'[|?"\']'
for i in range(len(df1)):
    name = re.sub(pattern_to_eliminate, '',df1.loc[i].book_name)
    path = "books/" + name + ".txt"
    with open(path,'w') as file:
        file.write(str(df1.loc[i].book_content))

        
# Saving each book_name and writer_name is csv file
df2 = df1[['book_name','writer_name']]
df2.to_csv(r"book_name_and_writer.csv", index=False)
df2
# Out:
#                                  book_name       writer_name
# 0                                     চিঠি              রিদা
# 1                             পাহাড়ের চূড়া      eshrat imroz
# 2                                   পথশিশু              রিদা
# 3           সুবিমলবাবুর স্মরণীয় বাস জার্নি       Anik Biswas
# 4                     কে তুমি  (শেষ পর্ব )  Easin Arfat Moin
# 5                                  টিভিকথন       Anik Biswas
# 6                             আমি(শেষপর্ব)      eshrat imroz
# 7                              আমি (পর্ব৭)      eshrat imroz
# 8                              আমি (পর্ব৬)      eshrat imroz
# 9                              আমি (পর্ব৫)      eshrat imroz
# 10                                  আসক্তি       Anik Biswas
# 11                             আমি (পর্ব৪)      eshrat imroz
# 12                       প্রিয় জয়ন্ত স্যার       Anik Biswas
# 13                             আমি (পর্ব৩)      eshrat imroz
# 14                             আমি (পর্ব২)      eshrat imroz
# 15                              আমি চঞ্চলা              Anik
# 16                                     আমি      eshrat imroz
# 17                              জিহাদ বাবু      eshrat imroz
# 18                            রোহান বিল্লা      eshrat imroz
# 19                  তুমি অন্যনা (শেষ পর্ব)      eshrat imroz
# 20                    নীল দ্বীপ (শেষ পর্ব)      eshrat imroz
# 21                      নীল দ্বীপ (পর্ব ৭)      eshrat imroz
# 22                                 অপেক্ষা              রিদা
# 23                                আমি এমনই       Anik Biswas
# 24                    তুমি অন্যনা (পর্ব ৭)      eshrat imroz
# 25                      নীল দ্বীপ (পর্ব ৬)      eshrat imroz
# 26                       নীল দ্বীপ (পর্ব৩)      eshrat imroz
# 27                       পরীক্ষার পূর্বদিন       Anik Biswas
# 28                   তুমি অনন্যা  (পর্ব ৬)      eshrat imroz
# 29                      নীল দ্বীপ (পর্ব ৫)      eshrat imroz
# 30                    নীল দ্বীপ  ( পর্ব ৪)      eshrat imroz
# 31                   তুমি অনন্যা  (পর্ব ৫)      eshrat imroz
# 32                       নীল দ্বীপ (পর্ব২)      eshrat imroz
# 33                               নীল দ্বীপ      eshrat imroz
# 34                    তুমি অনন্যা (পর্ব ৪)      eshrat imroz
# 35                দেখা হয় নাই চক্ষু মেলিয়া       Anik Biswas
# 36                              খাঁটি পাগল       Anik Biswas
# 37                               ডাবল জিরো       Anik Biswas
# 38                    তুমি অনন্যা (পর্ব ৩)      eshrat imroz
# 39                                     রাত              Anik
# 40                   তুমি অনন্যা (পর্ব ০২)      eshrat imroz
# 41                             তুমি অনন্যা      eshrat imroz
# 42                              রিক্সাচালক              রিদা
# 43                                জুতা চোর       Anik Biswas
# 44                                   বটমূল              রিদা
# 45                                     শেষ              Anik
# 46                                 কে তুমি  Easin Arfat Moin
# 47                       আশ্চর্য এক সুগন্ধ              রিদা
# 48          ধাপ্পাবাজ বাপ্পা অথবা ধাপ্পাদা       Anik Biswas
# 49                         পড়ন্ত বিকেলে...              রিদা
# 50                        হাস্যকর এক কাণ্ড       Anik Biswas
# 51                            অদ্ভুত-উদ্ভট       Anik Biswas
# 52                            ওগো বিদেশিনী       Anik Biswas
# 53                              কুলফিওয়ালা       Anik Biswas
# 54                                 ~পিল্টু       Anik Biswas
# 55                                 সে.....              রিদা
# 56                             মাথা ব্যাথা              Anik
# 57                        দার্শনিক ফল্টুদা       Anik Biswas
# 58                               নিদ্রাহীন       Anik Biswas
# 59                                   শিকার       Anik Biswas
# 60                      ফল্টুদার পরিচয়পর্ব       Anik Biswas
# 61                              প্রতিবিম্ব       Anik Biswas
# 62   ছোট দাদুর বাড়িতে কয়েকদিন.....(পর্ব ১)              রিদা
# 63                           কেমন আছো তুমি       Anik Biswas
# 64                পাশের বিল্ডিং এর ছাদে...              রিদা
# 65                 Birthday যখন Foolday!!🎶              রিদা
# 66                          আবার ফিরে দেখা       Anik Biswas
# 67                                   আসক্ত       Anik Biswas
# 68                   কবরস্থানের মাঠে একরাত              রিদা
# 69                           শুভ্র ও রাইসা              রিদা
# 70                       উধাও ||  পর্ব - ২             অর্পন
# 71                                প্রিয় মা       Anik Biswas
# 72                               অদ্ভুতুড়ে       Anik Biswas
# 73                               কে ছিল???              রিদা
# 74                        উধাও  || পর্ব -১             অর্পন
# 75                নাম হীন গল্প - শেষের অংশ         বিজয় ঘোষ
# 76                      সপ্ন যখন হ য ব র ল              সিকন
# 77                নাম হীন গল্প - প্রথম অংশ         বিজয় ঘোষ
# 78                  আমরা তো সবাই মানুষ!!!!              রিদা
# 79                         মিষ্টি ভালোবাসা              রিদা
# 80                   "রহস্যময়ী সেই ফোন কল"            Bristy
# 81                                   করোনা              রিদা
# 82                     সব পেশাই কি সমান???              রিদা
# 83                           কিছু করার নেই       Anik Biswas
# 84                                 ছোটগল্প       Anik Biswas
# 85                                 হ্যাবলা       Anik Biswas
# 86                                   সেদিন       Anik Biswas
# 87                                  চিরকুট       Anik Biswas
# 88                                   লায়লা             অর্পন
# 89                                   অর্পন              Anik
# 90                        যখন সন্ধ্যা নামে       Anik Biswas
# 91                                      ভয়              Anik
# 92                                    মিঠু       Anik Biswas
# 93                       কয়েকদিন হাসপাতালে       Anik Biswas
# 94                                   বন্ধু       Anik Biswas
# 95                                  অনুকথন       Anik Biswas
# 96                           অ্যাক্সিডেন্ট       Anik Biswas
# 97                                ভয়ের রাত       Anik Biswas
# 98                           অমাবস্যার রাত              Anik
# 99                              দৃষ্টিগোচর              Anik
# 100                                  বিলাপ              Anik

# %% [markdown]
# **Explain what you did and what are the challange you've faced doing this exercise...**

# %% [markdown]
# # Ans:
# # My approach
# I used Selenium to extract dynamic data from the website and then used beautiful soup to iterate through the stories and find book name,author name, and the book_contents which I later stored in separate lists.
# Again stored the scraped contents in a dictionary setting keys as instructed. Converted the dictionary into a dataframe and then converting it to csv file by the name Kathika and saved it in my local machine.
# Then i searched through book_content column of the dataframe if there were any mathches with html elements returning boolean type value and stored them in a separate column named contains_html.True denotes containing html elements.to check if there are any html elements in book_contents I used value_counts function of the contains_html column and it returned false for every item. checked if I was able to collect every book from the website. Then grouped the dataframe
# by writer_name against book_name and counted the number of books each writer has posted later storing it as a pandas series. Printed them by acessing index and value of the series. Saved books containg book_content as txt file naming them as book_name. Finally saving each book_name and writer_name is csv file.
#
# # Challenges Faced
# First challenge was to scrap dynamic values from the website. As BeautifulSoup can't do that, then I found selenium.Used selenium for the first time.
# I wasn't that much familiar with regex or the re library. It took some time to learn the basics.

# %% [markdown]
# # what will you submit once exam is over?
#
# 1. Provide complete jupyter notebook script.
# 2. all the file you got after running the script for the last time.
# 3. zip all the files and submit by following email instruction
